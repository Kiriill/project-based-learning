# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiriill/project-based-learning/blob/master/spoken_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# Keyword spotting model
#
# Objective: Train model to predict which of 35
# words are present in audio files
#
# Kiriill Butler 7 Sep 2026
#
